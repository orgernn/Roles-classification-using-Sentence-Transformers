# %% [markdown]
# <a href="https://colab.research.google.com/github/orgernn/Roles-classification-using-Sentence-Transformers/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5+5)
# Out:
# 10
